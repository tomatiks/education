# %% [markdown]
# ## Q-learning
# (3 points)
#
# This notebook will guide you through implementation of vanilla Q-learning algorithm.
#
# You need to implement QLearningAgent (follow instructions for each method) and use it on a number of tests below.

# %%
# XVFB will be launched if you run on a server
import os
# if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
#     !bash ../xvfb start
#     %env DISPLAY = : 1

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# %%writefile qlearning.py
from collections import defaultdict
import random
import math
import numpy as np


class QLearningAgent:
    def __init__(self, alpha, epsilon, discount, get_legal_actions):
        """
        Q-Learning Agent
        based on http://inst.eecs.berkeley.edu/~cs188/sp09/pacman.html
        Instance variables you have access to
          - self.epsilon (exploration prob)
          - self.alpha (learning rate)
          - self.discount (discount rate aka gamma)

        Functions you should use
          - self.get_legal_actions(state) {state, hashable -> list of actions, each is hashable}
            which returns legal actions for a state
          - self.get_qvalue(state,action)
            which returns Q(state,action)
          - self.set_qvalue(state,action,value)
            which sets Q(state,action) := value

        !!!Important!!!
        Note: please avoid using self._qValues directly. 
            There's a special self.get_qvalue/set_qvalue for that.
        """

        self.get_legal_actions = get_legal_actions
        self._qvalues = defaultdict(lambda: defaultdict(lambda: 0))
        self.alpha = alpha
        self.epsilon = epsilon
        self.discount = discount

    def get_qvalue(self, state, action):
        """ Returns Q(state,action) """
        return self._qvalues[state][action]

    def set_qvalue(self, state, action, value):
        """ Sets the Qvalue for [state,action] to the given value """
        self._qvalues[state][action] = value

    #---------------------START OF YOUR CODE---------------------#

    def get_value(self, state):
        """
        Compute your agent's estimate of V(s) using current q-values
        V(s) = max_over_action Q(state,action) over possible actions.
        Note: please take into account that q-values can be negative.
        """
        possible_actions = self.get_legal_actions(state)

        # If there are no legal actions, return 0.0
        if len(possible_actions) == 0:
            return 0.0

        value = max([self._qvalues[state][action] for action in possible_actions])

        return value

    def update(self, state, action, reward, next_state):
        """
        You should do your Q-Value update here:
           Q(s,a) := (1 - alpha) * Q(s,a) + alpha * (r + gamma * V(s'))
        """

        # agent parameters
        gamma = self.discount
        learning_rate = self.alpha
    
        qval = self._qvalues[state][action]
        qval = (1-learning_rate) * qval + learning_rate * (reward + gamma*self.get_value(next_state))

        self.set_qvalue(state, action, qval )

    def get_best_action(self, state):
        """
        Compute the best action to take in a state (using current q-values). 
        """
        possible_actions = self.get_legal_actions(state)

        # If there are no legal actions, return None
        if len(possible_actions) == 0:
            return None

        best_action = possible_actions[np.argmax([self._qvalues[state][action] for action in possible_actions])]
    
#         print(f'Qas = {[self.get_qvalue(state, a) for a in possible_actions]}')
#         print(f'Qas = {[self._qvalues[state][action] for action in possible_actions]}')
#         print(f'argmax = {np.argmax([self._qvalues[state][action] for action in possible_actions])}')
        
        return best_action

    def get_action(self, state):
        """
        Compute the action to take in the current state, including exploration.  
        With probability self.epsilon, we should take a random action.
            otherwise - the best policy action (self.getPolicy).

        Note: To pick randomly from a list, use random.choice(list). 
              To pick True or False with a given probablity, generate uniform number in [0, 1]
              and compare it with your probability
        """

        # Pick Action
        possible_actions = self.get_legal_actions(state)
        action = None

        # If there are no legal actions, return None
        if len(possible_actions) == 0:
            return None

        # agent parameters:
        epsilon = self.epsilon

        if np.random.uniform() < epsilon:
            action = np.random.choice(possible_actions)
        else:
            action = self.get_best_action(state)

        return action
# Out:
# Overwriting qlearning.py

# %% [markdown]
# ### Try it on taxi
#
# Here we use the qlearning agent on taxi env from openai gym.
# You will need to insert a few agent functions here.

# %%
from collections import defaultdict
l = defaultdict(lambda: defaultdict(lambda: 0))

# %%
l
# Out:
# defaultdict(<function __main__.<lambda>>,
#             {'f': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {}),
#              'ff': defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#                          {1: 0, 2: 0, 6: 0, 11: 0})})

# %%
import gym
env = gym.make("Taxi-v2")

n_actions = env.action_space.n

# %%
from qlearning import QLearningAgent

agent = QLearningAgent(alpha=0.5, epsilon=0.25, discount=0.99,
                       get_legal_actions=lambda s: range(n_actions))

# %%
def play_and_train(env, agent, t_max=10**4):
    """
    This function should 
    - run a full game, actions given by agent's e-greedy policy
    - train agent using agent.update(...) whenever it is possible
    - return total reward
    """
    total_reward = 0.0
    s = env.reset()

    for t in range(t_max):
        # get agent to pick action given state s.
        a = agent.get_action(s)

        next_s, r, done, _ = env.step(a)

        # train (update) agent for state s
        agent.update(s, a, r, next_s)

        s = next_s
        total_reward += r
        if done:
            break

    return total_reward

# %%
from IPython.display import clear_output

rewards = []
for i in range(1000):
    rewards.append(play_and_train(env, agent))
    agent.epsilon *= 0.99

    if i % 100 == 0:
        clear_output(True)
        print('eps =', agent.epsilon, 'mean reward =', np.mean(rewards[-10:]))
        plt.plot(rewards)
        plt.show()
# Out:
# eps = 2.9191091959171894e-05 mean reward = 9.4

# %% [markdown]
# # Binarized state spaces
#
# Use agent to train efficiently on CartPole-v0.
# This environment has a continuous set of possible states, so you will have to group them into bins somehow.
#
# The simplest way is to use `round(x,n_digits)` (or numpy round) to round real number to a given amount of digits.
#
# The tricky part is to get the n_digits right for each state to train effectively.
#
# Note that you don't need to convert state to integers, but to __tuples__ of any kind of values.

# %%
env = gym.make("CartPole-v0")
n_actions = env.action_space.n

print("first state:%s" % (env.reset()))
plt.imshow(env.render('rgb_array'))
env.close()
# Out:
# first state:[ 0.03365105  0.02688757  0.02319385 -0.01351907]

# %% [markdown]
# ### Play a few games
#
# We need to estimate observation distributions. To do so, we'll play a few games and record all states.

# %%
all_states = []
for _ in range(1000):
    all_states.append(env.reset())
    done = False
    while not done:
        s, r, done, _ = env.step(env.action_space.sample())
        all_states.append(s)
        if done:
            break

all_states = np.array(all_states)

for obs_i in range(env.observation_space.shape[0]):
    plt.hist(all_states[:, obs_i], bins=20)
    plt.show()

# %% [markdown]
# ## Binarize environment

# %%
from gym.core import ObservationWrapper


class Binarizer(ObservationWrapper):

    def observation(self, state):

        # state = <round state to some amount digits.>
        # hint: you can do that with round(x,n_digits)
        # you will need to pick a different n_digits for each dimension
        
        state[0] = round(state[0],1)
        state[2] = round(state[2],2)
        state[1] = round(state[1],1)
        state[3] = round(state[3],1)

        return tuple(state)

# %%
env = Binarizer(gym.make("CartPole-v0"))

# %%
all_states = []
for _ in range(1000):
    all_states.append(env.reset())
    done = False
    while not done:
        s, r, done, _ = env.step(env.action_space.sample())
        all_states.append(s)
        if done:
            break

all_states = np.array(all_states)

for obs_i in range(env.observation_space.shape[0]):

    plt.hist(all_states[:, obs_i], bins=20)
    plt.show()

# %% [markdown]
# ## Learn binarized policy
#
# Now let's train a policy that uses binarized state space.
#
# __Tips:__
# * If your binarization is too coarse, your agent may fail to find optimal policy. In that case, change binarization.
# * If your binarization is too fine-grained, your agent will take much longer than 1000 steps to converge. You can either increase number of iterations and decrease epsilon decay or change binarization.
# * Having 10^3 ~ 10^4 distinct states is recommended (`len(QLearningAgent._qvalues)`), but not required.
# * A reasonable agent should get to an average reward of >=50.

# %%
agent = QLearningAgent(alpha=0.5, epsilon=0.4, discount=1,
                       get_legal_actions=lambda s: range(n_actions))

# %%
rewards = []
for i in range(10000):
    rewards.append(play_and_train(env, agent))
    #agent.epsilon *= 0.999
    
    #if i == 7000:
    #    agent.alpha = 0.2
    # OPTIONAL YOUR CODE: adjust epsilon
    if i % 100 == 0:
        clear_output(True)
        print('eps =', agent.epsilon, 'mean reward =', np.mean(rewards[-10:]))
        plt.plot(rewards)
        plt.show()
# Out:
# eps = 0.4 mean reward = 64.6

# %%
rewards = []
for i in range(1000):
    rewards.append(play_and_train(env, agent))
      
   # agent.epsilon *= 0.99
    # OPTIONAL YOUR CODE: adjust epsilon
    if i % 100 == 0:
        clear_output(True)
        print('eps =', agent.epsilon, 'mean reward =', np.mean(rewards[-10:]))
        plt.plot(rewards)
        plt.show()
# Out:
# eps = 4.472161251727821e-05 mean reward = 85.2

# %%
np.mean(rewards[-100:])
# Out:
# 72.31

# %%
env.reset()
# Out:
# (0.023425, -0.042, 0.035, -0.01)

# %%
agent._qvalues
# Out:
# defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>>,
#             {(-0.0,
#               -0.02,
#               -0.008,
#               0.011): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5}),
#              (-0.0,
#               -0.21,
#               -0.008,
#               0.301): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               -0.02,
#               -0.002,
#               0.006): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.21,
#               -0.001,
#               0.299): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               -0.02,
#               0.005,
#               0.005): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.21,
#               0.005,
#               0.3): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.41,
#               0.011,
#               0.594): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.21,
#               0.023,
#               0.304): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.41,
#               0.029,
#               0.604): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.6,
#               0.041,
#               0.906): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.8,
#               0.059,
#               1.211): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.99,
#               0.083,
#               1.521): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.8,
#               0.113,
#               1.256): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -1.0,
#               0.139,
#               1.582): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.8,
#               0.17,
#               1.335): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.2,
#               -1.0,
#               0.197,
#               1.676): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.2,
#               -1.2,
#               0.23,
#               2.023): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0}),
#              (-0.0,
#               0.01,
#               -0.048,
#               0.03): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {1: 0.5}),
#              (-0.0,
#               0.21,
#               -0.048,
#               -0.277): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               0.01,
#               -0.053,
#               0.0): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.18,
#               -0.053,
#               0.275): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.38,
#               -0.048,
#               0.551): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.57,
#               -0.037,
#               0.828): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.76,
#               -0.02,
#               1.109): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.57,
#               0.002,
#               0.81): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.37,
#               0.018,
#               0.518): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.57,
#               0.029,
#               0.816): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.76,
#               0.045,
#               1.118): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.96,
#               0.067,
#               1.424): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.77,
#               0.096,
#               1.153): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.96,
#               0.119,
#               1.474): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.2,
#               -0.77,
#               0.148,
#               1.221): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.2,
#               -0.97,
#               0.173,
#               1.556): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.2,
#               -1.16,
#               0.204,
#               1.897): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.2,
#               -1.36,
#               0.242,
#               2.246): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0}),
#              (0.0,
#               -0.05,
#               -0.022,
#               0.02): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5}),
#              (0.0,
#               -0.24,
#               -0.021,
#               0.306): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               -0.44,
#               -0.015,
#               0.592): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               -0.63,
#               -0.003,
#               0.88): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               -0.83,
#               0.014,
#               1.171): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               -0.63,
#               0.038,
#               0.883): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.83,
#               0.055,
#               1.187): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -1.02,
#               0.079,
#               1.497): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.83,
#               0.109,
#               1.23): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.64,
#               0.133,
#               0.973): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.83,
#               0.153,
#               1.305): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -1.03,
#               0.179,
#               1.641): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -1.23,
#               0.212,
#               1.984): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0}),
#              (0.0,
#               0.03,
#               -0.009,
#               0.002): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5}),
#              (0.0,
#               -0.16,
#               -0.009,
#               0.292): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               -0.36,
#               -0.003,
#               0.582): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               -0.55,
#               0.009,
#               0.874): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               -0.75,
#               0.026,
#               1.169): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               -0.94,
#               0.05,
#               1.47): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               -0.75,
#               0.079,
#               1.194): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.94,
#               0.103,
#               1.51): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               -0.75,
#               0.133,
#               1.251): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.95,
#               0.158,
#               1.582): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.75,
#               0.19,
#               1.343): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.95,
#               0.217,
#               1.688): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0}),
#              (0.0,
#               0.04,
#               0.038,
#               -0.019): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.6000000000000001,
#                           1: 0}),
#              (0.0,
#               -0.15,
#               0.037,
#               0.285): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               0.04,
#               0.043,
#               0.005): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               0.24,
#               0.043,
#               -0.274): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               0.43,
#               0.037,
#               -0.553): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               0.24,
#               0.026,
#               -0.249): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               0.04,
#               0.021,
#               0.052): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               -0.16,
#               0.022,
#               0.352): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               -0.35,
#               0.029,
#               0.651): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               -0.16,
#               0.043,
#               0.368): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               0.04,
#               0.05,
#               0.089): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               -0.16,
#               0.052,
#               0.397): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               -0.35,
#               0.06,
#               0.705): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               -0.16,
#               0.074,
#               0.432): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               -0.36,
#               0.082,
#               0.747): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               -0.55,
#               0.097,
#               1.064): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               -0.75,
#               0.119,
#               1.386): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               -0.55,
#               0.146,
#               1.133): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.75,
#               0.169,
#               1.467): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.95,
#               0.198,
#               1.808): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -1.14,
#               0.234,
#               2.155): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0}),
#              (-0.0,
#               0.0,
#               0.002,
#               -0.003): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.6990000000000001}),
#              (-0.0,
#               0.2,
#               0.002,
#               -0.295): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.6000000000000001}),
#              (-0.0,
#               0.39,
#               -0.004,
#               -0.587): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               0.2,
#               -0.015,
#               -0.295): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.6990000000000001,
#                           1: 0}),
#              (-0.0,
#               0.0,
#               -0.021,
#               -0.007): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.6000000000000001}),
#              (-0.0,
#               0.2,
#               -0.022,
#               -0.307): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               0.0,
#               -0.028,
#               -0.021): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               0.2,
#               -0.028,
#               -0.322): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               0.4,
#               -0.035,
#               -0.624): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               0.2,
#               -0.047,
#               -0.342): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               0.4,
#               -0.054,
#               -0.649): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               0.2,
#               -0.067,
#               -0.374): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               0.01,
#               -0.074,
#               -0.103): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               0.2,
#               -0.076,
#               -0.418): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               0.4,
#               -0.085,
#               -0.734): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               0.21,
#               -0.099,
#               -0.469): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               0.4,
#               -0.109,
#               -0.791): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               0.21,
#               -0.125,
#               -0.535): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               0.41,
#               -0.135,
#               -0.864): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               0.6,
#               -0.153,
#               -1.196): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.1,
#               0.8,
#               -0.176,
#               -1.532): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               0.61,
#               -0.207,
#               -1.3): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.1,
#               0.8,
#               -0.233,
#               -1.649): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0}),
#              (-0.0,
#               0.01,
#               0.048,
#               -0.046): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5}),
#              (-0.0,
#               -0.19,
#               0.047,
#               0.262): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.38,
#               0.052,
#               0.569): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.58,
#               0.064,
#               0.878): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.78,
#               0.081,
#               1.189): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.97,
#               0.105,
#               1.506): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.78,
#               0.135,
#               1.248): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.58,
#               0.16,
#               1.001): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.39,
#               0.18,
#               0.762): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.59,
#               0.195,
#               1.106): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.2,
#               -0.79,
#               0.217,
#               1.453): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0}),
#              (-0.0,
#               -0.01,
#               -0.017,
#               -0.037): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5}),
#              (-0.0,
#               -0.21,
#               -0.017,
#               0.25): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.6000000000000001,
#                           1: 0}),
#              (-0.0,
#               -0.4,
#               -0.012,
#               0.537): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.6,
#               -0.002,
#               0.826): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.4,
#               0.015,
#               0.533): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.6,
#               0.025,
#               0.83): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.4,
#               0.042,
#               0.545): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.6,
#               0.053,
#               0.851): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.4,
#               0.07,
#               0.576): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.6,
#               0.082,
#               0.889): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.41,
#               0.099,
#               0.623): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.6,
#               0.112,
#               0.946): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.41,
#               0.131,
#               0.69): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.22,
#               0.144,
#               0.441): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.02,
#               0.153,
#               0.197): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.22,
#               0.157,
#               0.534): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.03,
#               0.168,
#               0.295): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               0.17,
#               0.174,
#               0.06): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               0.36,
#               0.175,
#               -0.174): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               0.55,
#               0.172,
#               -0.406): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               0.74,
#               0.163,
#               -0.64): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               0.54,
#               0.151,
#               -0.301): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               0.35,
#               0.145,
#               0.035): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               0.54,
#               0.145,
#               -0.209): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               0.34,
#               0.141,
#               0.126): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               0.15,
#               0.144,
#               0.46): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               0.34,
#               0.153,
#               0.216): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               0.14,
#               0.157,
#               0.552): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.05,
#               0.168,
#               0.89): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.25,
#               0.186,
#               1.231): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.45,
#               0.211,
#               1.575): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0}),
#              (0.0,
#               -0.02,
#               0.008,
#               -0.034): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {1: 0.5}),
#              (0.0,
#               0.17,
#               0.008,
#               -0.324): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               -0.02,
#               0.001,
#               -0.029): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               -0.22,
#               0.001,
#               0.264): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               -0.42,
#               0.006,
#               0.557): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.8990000000000001,
#                           1: 0}),
#              (0.0,
#               -0.61,
#               0.017,
#               0.852): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.6990000000000001}),
#              (0.0,
#               -0.42,
#               0.034,
#               0.564): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.6000000000000001}),
#              (-0.0,
#               -0.22,
#               0.045,
#               0.283): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               -0.03,
#               0.051,
#               0.005): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               0.17,
#               0.051,
#               -0.271): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.03,
#               0.046,
#               0.037): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               0.17,
#               0.046,
#               -0.241): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.03,
#               0.042,
#               0.066): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               0.17,
#               0.043,
#               -0.213): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               0.36,
#               0.039,
#               -0.492): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               0.55,
#               0.029,
#               -0.772): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               0.75,
#               0.013,
#               -1.056): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               0.94,
#               -0.008,
#               -1.344): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               0.75,
#               -0.035,
#               -1.054): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               0.55,
#               -0.056,
#               -0.772): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               0.36,
#               -0.071,
#               -0.498): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.1,
#               0.56,
#               -0.081,
#               -0.812): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               0.36,
#               -0.097,
#               -0.546): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               0.17,
#               -0.108,
#               -0.285): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               -0.02,
#               -0.114,
#               -0.028): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               -0.22,
#               -0.114,
#               0.226): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.1,
#               -0.02,
#               -0.11,
#               -0.1): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               -0.21,
#               -0.112,
#               0.156): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               -0.41,
#               -0.109,
#               0.411): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.1,
#               -0.21,
#               -0.101,
#               0.086): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.1,
#               -0.02,
#               -0.099,
#               -0.236): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.1,
#               0.18,
#               -0.104,
#               -0.559): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               -0.01,
#               -0.115,
#               -0.3): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.1,
#               0.18,
#               -0.121,
#               -0.627): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.1,
#               0.38,
#               -0.133,
#               -0.955): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               0.19,
#               -0.152,
#               -0.707): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               -0.01,
#               -0.167,
#               -0.466): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.1,
#               0.19,
#               -0.176,
#               -0.806): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               -0.0,
#               -0.192,
#               -0.573): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               -0.19,
#               -0.203,
#               -0.347): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.1,
#               0.0,
#               -0.21,
#               -0.696): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0}),
#              (-0.0,
#               0.01,
#               0.047,
#               0.001): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5}),
#              (-0.0,
#               -0.19,
#               0.047,
#               0.308): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               0.01,
#               0.053,
#               0.03): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               0.2,
#               0.054,
#               -0.245): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               0.01,
#               0.049,
#               0.064): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               0.2,
#               0.05,
#               -0.213): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               0.39,
#               0.046,
#               -0.49): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               0.59,
#               0.036,
#               -0.767): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               0.39,
#               0.021,
#               -0.464): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               0.59,
#               0.011,
#               -0.75): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               0.39,
#               -0.004,
#               -0.453): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               0.2,
#               -0.013,
#               -0.162): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               0.0,
#               -0.016,
#               0.127): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               0.2,
#               -0.013,
#               -0.171): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               0.0,
#               -0.017,
#               0.118): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               0.2,
#               -0.014,
#               -0.18): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               0.0,
#               -0.018,
#               0.108): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               0.2,
#               -0.016,
#               -0.191): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               0.39,
#               -0.02,
#               -0.488): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               0.59,
#               -0.029,
#               -0.787): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               0.39,
#               -0.045,
#               -0.504): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               0.2,
#               -0.055,
#               -0.226): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               0.01,
#               -0.06,
#               0.049): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               -0.19,
#               -0.059,
#               0.322): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.1,
#               0.01,
#               -0.052,
#               0.012): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               -0.19,
#               -0.052,
#               0.288): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               -0.38,
#               -0.046,
#               0.563): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.1,
#               -0.19,
#               -0.035,
#               0.256): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.1,
#               -0.38,
#               -0.03,
#               0.538): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (0.0,
#               -0.18,
#               -0.019,
#               0.236): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (0.0,
#               -0.38,
#               -0.014,
#               0.523): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
# ...
#               -1.366): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0}),
#              (-0.0,
#               -0.0,
#               0.023,
#               -0.04): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5}),
#              (-0.0,
#               -0.2,
#               0.022,
#               0.26): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.4,
#               0.028,
#               0.56): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.6000000000000001}),
#              (-0.0,
#               -0.2,
#               0.039,
#               0.276): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.4,
#               0.044,
#               0.581): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.2,
#               0.056,
#               0.302): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.4,
#               0.062,
#               0.612): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.59,
#               0.074,
#               0.924): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.4,
#               0.093,
#               0.655): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.6,
#               0.106,
#               0.976): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.4,
#               0.125,
#               0.718): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.6,
#               0.14,
#               1.047): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.41,
#               0.161,
#               0.802): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.21,
#               0.177,
#               0.563): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.41,
#               0.188,
#               0.906): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.61,
#               0.206,
#               1.251): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.2,
#               -0.8,
#               0.231,
#               1.601): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0}),
#              (-0.0,
#               -0.02,
#               -0.014,
#               -0.011): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {1: 0.5}),
#              (-0.0,
#               0.18,
#               -0.014,
#               -0.308): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               0.37,
#               -0.02,
#               -0.605): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               0.18,
#               -0.032,
#               -0.318): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.02,
#               -0.038,
#               -0.036): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               0.18,
#               -0.039,
#               -0.341): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.01,
#               -0.046,
#               -0.061): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               0.18,
#               -0.047,
#               -0.367): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.01,
#               -0.055,
#               -0.09): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.21,
#               -0.056,
#               0.185): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.4,
#               -0.053,
#               0.459): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               -0.21,
#               -0.043,
#               0.151): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.4,
#               -0.04,
#               0.429): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.6,
#               -0.032,
#               0.709): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.79,
#               -0.018,
#               0.991): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.59,
#               0.002,
#               0.693): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.4,
#               0.016,
#               0.401): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.59,
#               0.024,
#               0.699): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.4,
#               0.038,
#               0.414): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.21,
#               0.046,
#               0.133): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.01,
#               0.049,
#               -0.144): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               0.18,
#               0.046,
#               -0.421): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               0.38,
#               0.038,
#               -0.699): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               0.18,
#               0.024,
#               -0.395): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.01,
#               0.016,
#               -0.095): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.21,
#               0.014,
#               0.203): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.4,
#               0.018,
#               0.5): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.21,
#               0.028,
#               0.213): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.4,
#               0.032,
#               0.514): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.6,
#               0.042,
#               0.817): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.8,
#               0.059,
#               1.123): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.2,
#               -0.99,
#               0.081,
#               1.433): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.2,
#               -1.19,
#               0.11,
#               1.75): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.2,
#               -1.38,
#               0.145,
#               2.075): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.2,
#               -1.58,
#               0.186,
#               2.409): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.3,
#               -1.78,
#               0.235,
#               2.752): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0}),
#              (-0.0,
#               -0.03,
#               0.036,
#               0.036): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {1: 0.5}),
#              (-0.0,
#               0.17,
#               0.037,
#               -0.245): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               0.36,
#               0.032,
#               -0.526): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               0.17,
#               0.021,
#               -0.223): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.03,
#               0.017,
#               0.076): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               0.17,
#               0.018,
#               -0.211): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.03,
#               0.014,
#               0.087): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.22,
#               0.016,
#               0.384): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.42,
#               0.024,
#               0.682): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               -0.22,
#               0.037,
#               0.397): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.0,
#               -0.42,
#               0.045,
#               0.701): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.0,
#               -0.23,
#               0.059,
#               0.423): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.42,
#               0.068,
#               0.733): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.62,
#               0.082,
#               1.047): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0.5,
#                           1: 0}),
#              (-0.1,
#               -0.81,
#               0.103,
#               1.364): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.62,
#               0.13,
#               1.105): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.43,
#               0.153,
#               0.856): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.23,
#               0.17,
#               0.615): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              (-0.1,
#               -0.04,
#               0.182,
#               0.38): defaultdict(<function qlearning.QLearningAgent.__init__.<locals>.<lambda>.<locals>.<lambda>>, {0: 0,
#                           1: 0.5}),
#              ...})

# %%
def play_and_train_watch(env, agent, t_max=10**4):
    """
    This function should 
    - run a full game, actions given by agent's e-greedy policy
    - train agent using agent.update(...) whenever it is possible
    - return total reward
    """
    total_reward = 0.0
    s = env.reset()

    for t in range(t_max):
        # get agent to pick action given state s.
        a = agent.get_action(s)

        next_s, r, done, _ = env.step(a)
        env.render()

        # train (update) agent for state s
        agent.update(s, a, r, next_s)

        s = next_s
        total_reward += r
        if done:
            break

    return total_reward

# %%
for i in range(40):
    play_and_train_watch(env,agent)
    
env.close()
